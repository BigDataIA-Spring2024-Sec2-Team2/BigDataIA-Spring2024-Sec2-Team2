# %%
# !pip install diagrams
from diagrams import Diagram, Cluster, Edge
from diagrams.programming.language import Python
from diagrams.custom import Custom
from diagrams.aws.storage import S3
from diagrams.aws.network import ELB
from diagrams.aws.compute import EC2
from diagrams.saas.analytics import Snowflake
from diagrams.onprem.workflow import Airflow
from diagrams.programming.framework import FastAPI
from urllib.request import urlretrieve
from diagrams.digitalocean.compute import Docker
from diagrams.onprem.database import Mongodb
from diagrams import Diagram, Cluster
from diagrams.programming.language import Python
from diagrams.gcp.storage import GCS
from diagrams.onprem.container import Crio

from diagrams import Diagram, Cluster, Edge
from diagrams.aws.storage import SimpleStorageServiceS3
from diagrams import Cluster, Diagram
from diagrams.programming.language import Python
from urllib.request import urlretrieve
from diagrams.custom import Custom
from diagrams.digitalocean.storage import Folder
from diagrams.oci.connectivity import DNS
from diagrams.elastic.beats import Filebeat

from diagrams import Diagram, Cluster, Edge
from diagrams.aws.compute import EC2
from diagrams.aws.compute import Lambda
from diagrams.aws.ml import Sagemaker
from diagrams.onprem.queue import Kafka
from diagrams.aws.storage import SimpleStorageServiceS3
from diagrams import Cluster, Diagram
from diagrams.aws.general import Users
from diagrams.aws.analytics import Athena
from diagrams.azure.web import AppServiceDomains
from diagrams.programming.language import Python
from diagrams.custom import Custom
from urllib.request import urlretrieve
from diagrams.onprem.workflow import Airflow
from diagrams.programming.framework import Fastapi

from diagrams.gcp.compute import GCF
from diagrams.gcp.api import Endpoints

# %%
graph_attr = {
  "width": "700",
  "height": "700"}

cluster_attr = {
    "bgcolor": "white",
    "fontsize":"15"
}

# %%
from diagrams.gcp.analytics import PubSub
with Diagram("\n\nArchitecture Diagram", show=False, graph_attr=graph_attr, direction="LR") as diag:
  with Cluster("", graph_attr=cluster_attr):

    snowflake1 = Snowflake("Sentiment score")
    snowflake2 = Snowflake("Predicted Stock Value")
    docker3 = Docker("Docker")


    airflow = Airflow("Airflow\ntrigger")
    cfa_website = DNS("CFA Websites")



    with Cluster("Web Scrapped Flow", graph_attr=cluster_attr):
      web_scrapped = Python("\nScrapping\nData")
      storage2 = GCS("GCP Bucket")
      storage1 = GCS("GCP Bucket")
      PubSub = PubSub("Pubsub Model")
      GCF1 = GCF("CLoud Function for Validation")
      GCF2 = GCF("CLoud Function for intercating with OpenAI")
      openai = Endpoints("Openai API")
      kaftka_data = Kafka("\nStremaing data \nin channels", fontsize="12")




    with Cluster("Historical Data Flow", graph_attr=cluster_attr):
      kaftka_data2 = Kafka("\nStremaing data \nin channels", fontsize="12")
      historical_data = Python("\nOne Month\nData Collection")
      process_data = Python("\nProcess Data\n")
      storage3 = GCS("GCP Bucket")
      snowpipe_url = "https://community.snowflake.com/profilephoto/7293r000000gz0f/M"
      snowpipe_icon = "openstack.png"
      urlretrieve(snowpipe_url, snowpipe_icon)
      snowpipe = Custom("Snowpipe \n\nData ingestion", snowpipe_icon, edge_label=" ", fontsize="15", x_pos="1", y_pos="1", fontweight="bold")



    # with Cluster("User End Flow", graph_attr=cluster_attr):

    #   operation_data = Python("\nMath\nFormula")
    #   fast_api_1 = FastAPI("Accept request \n Trrigers piepeline")
    #   mongodb = Mongodb("Stores user \nrelated data")
    # streamlit_icon = "openstack.png"
    # streamlit_url = "data:image/png;base64,..."
    # urlretrieve(streamlit_url, streamlit_icon)
    # streamlit_app = Custom("Streamlit \nWebapp", streamlit_icon, edge_label=" ", fontsize="12")
    # snowflake3 = Snowflake("Sentiment score")
    # snowflake4 = Snowflake("Predicted Stock Value")



cfa_website >> kaftka_data >> web_scrapped >> storage1 >> GCF1 >> storage2 >>  GCF2 >> openai >> GCF2 >> PubSub >> snowflake1

historical_data >> kaftka_data2 >> process_data >> storage3 >> snowpipe >> snowflake2
process_data >> snowflake2

# snowflake3 >> operation_data
# snowflake4 >> operation_data
# user >> streamlit_app >> fast_api_1 >> streamlit_app
# fast_api_1 >> operation_data >> streamlit_app
# streamlit_app >> mongodb >> streamlit_app

diag
# Out:
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label

# %%
from diagrams.gcp.analytics import PubSub
with Diagram("\n\nArchitecture Diagram", show=False, graph_attr=graph_attr, direction="LR") as diag:
  user = Users("Users", fontsize="12")

  with Cluster("User End Flow", graph_attr=cluster_attr):
    snowflake3 = Snowflake("Sentiment score")
    snowflake4 = Snowflake("Predicted Stock Value")
    docker3 = Docker("Docker")
    operation_data = Python("\nMath\nFormula")
    fast_api_1 = FastAPI("Accept request \n Trrigers piepeline")
    mongodb = Mongodb("Stores user \nrelated data")
  streamlit_icon = "openstack.png"
  streamlit_url = "data:image/png;base64,..."
  urlretrieve(streamlit_url, streamlit_icon)
  streamlit_app = Custom("Streamlit \nWebapp", streamlit_icon, edge_label=" ", fontsize="12")




snowflake3 >> operation_data
snowflake4 >> operation_data
user >> streamlit_app >> fast_api_1 >> streamlit_app
fast_api_1 >> operation_data >> streamlit_app
streamlit_app >> mongodb >> streamlit_app

diag
# Out:
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
# ...
#
# Architecture Diagram' size too small for label
